# %% [markdown]
# pip install geopandas

# %%
pip install geopandas
# Out:
# Requirement already satisfied: geopandas in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (0.10.2)
# Requirement already satisfied: fiona>=1.8 in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (from geopandas) (1.8.20)
# Requirement already satisfied: shapely>=1.6 in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (from geopandas) (1.8.0)
# Requirement already satisfied: pandas>=0.25.0 in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (from geopandas) (1.3.5)
# Requirement already satisfied: pyproj>=2.2.0 in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (from geopandas) (3.3.0)
# Requirement already satisfied: attrs>=17 in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (21.2.0)
# Requirement already satisfied: click-plugins>=1.0 in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: setuptools in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (58.0.4)
# Requirement already satisfied: munch in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: click>=4.0 in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (8.0.3)
# Requirement already satisfied: six>=1.7 in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (1.16.0)
# Requirement already satisfied: cligj>=0.5 in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: certifi in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (2021.10.8)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (from pandas>=0.25.0->geopandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (from pandas>=0.25.0->geopandas) (1.22.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (from pandas>=0.25.0->geopandas) (2021.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# This time series analysis hopes to find a coorelation between accident location, type of issue, time taken to resolve issue, time of day, day of week, and month of year. This will help predict when and where an accident is likely to happen.

# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

import descartes
import geopandas as gpd
from shapely.geometry import Point, Polygon

# %matplotlib inline

# %% [markdown]
# # Data Collection/Organization

# %%
file = 'Real-Time_Traffic_Incident_Reports.csv'

# %%
df = pd.read_csv(file, parse_dates=['Published Date', 'Status Date'])

df.head()
#I wanted to see what the data looked like in pandas.
# Out:
#                                    Traffic Report ID  \
# 0  C163BCD1CF90C984E9EDA4DBA311BCA369A7D1A1_15288...
# 1  6B20382196FB454E9FD06A33E60142902A2F0706_15288...
# 2  2A7A84FC69D56A2C379C274D2F0831442D3E7B8E_15871...
# 3  89D3B75BB5932F10D25B5852A9902DA26C3DF11A_15871...
# 4  E7F9EFF0E81057A5C8FE41CABE4D9C6EEA82DAA0_15871...
#
#              Published Date  Issue Reported                Location  \
# 0 2018-06-13 06:35:59+00:00   Crash Service  (30.283797,-97.741906)
# 1 2018-06-13 10:15:36+00:00  Traffic Hazard  (30.339593,-97.700963)
# 2 2020-04-17 21:25:03+00:00    Crash Urgent  (30.329455,-97.638105)
# 3 2020-04-17 21:40:52+00:00  Traffic Hazard  (30.202806,-97.760701)
# 4 2020-04-17 21:00:55+00:00    Crash Urgent  (30.184265,-97.687339)
#
#     Latitude  Longitude                                      Address  \
# 0  30.283797 -97.741906                     W 21ST ST & GUADALUPE ST
# 1  30.339593 -97.700963                     400-717 E ANDERSON LN EB
# 2  30.329455 -97.638105  E US 290 HWY SVRD EB & EASTERN HEIGHTS BLVD
# 3  30.202806 -97.760701                          5300-blk S Ih 35 Sb
# 4  30.184265 -97.687339                    4500-4720 S Us 183 Hwy Sb
#
#      Status               Status Date
# 0  ARCHIVED 2018-06-13 09:00:03+00:00
# 1  ARCHIVED 2018-06-13 11:20:03+00:00
# 2  ARCHIVED 2020-04-17 21:55:03+00:00
# 3  ARCHIVED 2020-04-17 21:55:03+00:00
# 4  ARCHIVED 2020-04-17 23:30:04+00:00

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# The column names have spaces in them. This will prove to be a problem with creating visualizations later so I'm going to change the variable names for the applicable columns.

# %%
df=df.rename(columns = {'Published Date':'published_date'})
df=df.rename(columns = {'Status Date':'status_date'})
df=df.rename(columns = {'Issue Reported':'issue_reported'})
df=df.rename(columns = {'Traffic Report ID':'tr_ID'})
df.head()
# Out:
#                                                tr_ID  \
# 0  C163BCD1CF90C984E9EDA4DBA311BCA369A7D1A1_15288...
# 1  6B20382196FB454E9FD06A33E60142902A2F0706_15288...
# 2  2A7A84FC69D56A2C379C274D2F0831442D3E7B8E_15871...
# 3  89D3B75BB5932F10D25B5852A9902DA26C3DF11A_15871...
# 4  E7F9EFF0E81057A5C8FE41CABE4D9C6EEA82DAA0_15871...
#
#              published_date  issue_reported                Location  \
# 0 2018-06-13 06:35:59+00:00   Crash Service  (30.283797,-97.741906)
# 1 2018-06-13 10:15:36+00:00  Traffic Hazard  (30.339593,-97.700963)
# 2 2020-04-17 21:25:03+00:00    Crash Urgent  (30.329455,-97.638105)
# 3 2020-04-17 21:40:52+00:00  Traffic Hazard  (30.202806,-97.760701)
# 4 2020-04-17 21:00:55+00:00    Crash Urgent  (30.184265,-97.687339)
#
#     Latitude  Longitude                                      Address  \
# 0  30.283797 -97.741906                     W 21ST ST & GUADALUPE ST
# 1  30.339593 -97.700963                     400-717 E ANDERSON LN EB
# 2  30.329455 -97.638105  E US 290 HWY SVRD EB & EASTERN HEIGHTS BLVD
# 3  30.202806 -97.760701                          5300-blk S Ih 35 Sb
# 4  30.184265 -97.687339                    4500-4720 S Us 183 Hwy Sb
#
#      Status               status_date
# 0  ARCHIVED 2018-06-13 09:00:03+00:00
# 1  ARCHIVED 2018-06-13 11:20:03+00:00
# 2  ARCHIVED 2020-04-17 21:55:03+00:00
# 3  ARCHIVED 2020-04-17 21:55:03+00:00
# 4  ARCHIVED 2020-04-17 23:30:04+00:00

# %% [markdown]
# Exploring the Data and Converting Datatypes

# %%
df.shape
#big enough
# Out:
# (249650, 9)

# %% [markdown]
# There are 249,650 rows and 9 columns

# %%
df.describe()
#I assume I only get one column because it's the only numerical data type(float)
# Out:
#            Longitude
# count  249571.000000
# mean      -97.551690
# std         4.211096
# min       -98.816154
# 25%       -97.776950
# 50%       -97.734295
# 75%       -97.687038
# max         0.000000

# %% [markdown]
# # Data definition

# %%
df['Latitude'] = pd.to_numeric(df['Latitude'], errors = 'coerce') #Converting Latitude to numeric(float)
df.info()
#I also changed published/status date to datetime objects from string
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249650 entries, 0 to 249649
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tr_ID           249650 non-null  object
#  1   published_date  249650 non-null  datetime64[ns, UTC]
#  2   issue_reported  249650 non-null  object
#  3   Location        249107 non-null  object
#  4   Latitude        249525 non-null  float64
#  5   Longitude       249571 non-null  float64
#  6   Address         249650 non-null  object
#  7   Status          247957 non-null  object
#  8   status_date     249650 non-null  datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](2), float64(2), object(5)
# memory usage: 17.1+ MB

# %%
missing = pd.concat([df.isnull().sum(), 100 * df.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by='count')
# Out:
#                 count         %
# tr_ID               0  0.000000
# published_date      0  0.000000
# issue_reported      0  0.000000
# Address             0  0.000000
# status_date         0  0.000000
# Longitude          79  0.031644
# Latitude          125  0.050070
# Location          543  0.217505
# Status           1693  0.678149

# %%
#The columns are missing some values are:
#Longitude - 3%
#Latitude - 5%
#Location - 21%, This will be dropped later as it is redundant and has more null values
#Status - 67%, This column will not be used for this analysis, it only inidicates whether a incident is archived or 
#not. Everything in this dataset is archived.

# %%
df.dropna(subset=['Latitude'],inplace=True)
df.dropna(subset=['Longitude'],inplace=True)
#Dropping null values in the above columns

# %%
print(df.Latitude.min())
print(df.Longitude.max())
# Out:
# 0.0
# 0.0

# %% [markdown]
# Clearly we have more than NaN values to worry about. 0's don't help anything.

# %%
df = df[df.Latitude != 0]
df = df[df.Longitude != 0]

# %%
print(df.Latitude.min())
print(df.Longitude.max())
# Out:
# 30.003883
# -97.108986

# %%
df.describe()
# Out:
#             Latitude      Longitude
# count  249061.000000  249061.000000
# mean       30.301823     -97.733356
# std         0.093838       0.087198
# min        30.003883     -98.816154
# 25%        30.232048     -97.777123
# 50%        30.294401     -97.734380
# 75%        30.373815     -97.687431
# max        31.077333     -97.108986

# %% [markdown]
# This is much better.

# %% [markdown]
# ### Recheck the null values

# %%
missing = pd.concat([df.isnull().sum(), 100 * df.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by='count')
# Out:
#                 count         %
# tr_ID               0  0.000000
# published_date      0  0.000000
# issue_reported      0  0.000000
# Location            0  0.000000
# Latitude            0  0.000000
# Longitude           0  0.000000
# Address             0  0.000000
# status_date         0  0.000000
# Status           1687  0.677344

# %% [markdown]
# So I thought it may be better to create a new location variable as a float but there were far too many null values for the new split 'Location" data. Instances of null in Latitude increased by 46. I place inplace+True to solve.
#
# Status can likely be removed entirely as it does not really serve a purpose.

# %% [markdown]
# I'm dropping location becasue attempts to split and convert into float datatype created too many null values to be useful. Also, I already have Lat/Lon data to use.

# %%
df.drop(['Location'], axis=1, inplace=True) #(use this is Location show back up)
df.drop(['Status'], axis=1, inplace=True)
df.head(3)
# Out:
#                                                tr_ID  \
# 0  C163BCD1CF90C984E9EDA4DBA311BCA369A7D1A1_15288...
# 1  6B20382196FB454E9FD06A33E60142902A2F0706_15288...
# 2  2A7A84FC69D56A2C379C274D2F0831442D3E7B8E_15871...
#
#              published_date  issue_reported   Latitude  Longitude  \
# 0 2018-06-13 06:35:59+00:00   Crash Service  30.283797 -97.741906
# 1 2018-06-13 10:15:36+00:00  Traffic Hazard  30.339593 -97.700963
# 2 2020-04-17 21:25:03+00:00    Crash Urgent  30.329455 -97.638105
#
#                                        Address               status_date
# 0                     W 21ST ST & GUADALUPE ST 2018-06-13 09:00:03+00:00
# 1                     400-717 E ANDERSON LN EB 2018-06-13 11:20:03+00:00
# 2  E US 290 HWY SVRD EB & EASTERN HEIGHTS BLVD 2020-04-17 21:55:03+00:00

# %%
issue_date = df[['issue_reported', 'published_date', 'status_date']]
issue_date.head()
# Out:
#    issue_reported            published_date               status_date
# 0   Crash Service 2018-06-13 06:35:59+00:00 2018-06-13 09:00:03+00:00
# 1  Traffic Hazard 2018-06-13 10:15:36+00:00 2018-06-13 11:20:03+00:00
# 2    Crash Urgent 2020-04-17 21:25:03+00:00 2020-04-17 21:55:03+00:00
# 3  Traffic Hazard 2020-04-17 21:40:52+00:00 2020-04-17 21:55:03+00:00
# 4    Crash Urgent 2020-04-17 21:00:55+00:00 2020-04-17 23:30:04+00:00

# %% [markdown]
# Subtracting the published date from the status date will help find out how long these issues take to resolve which will be useful in helping avoid parts of town. The date and time are listed together, which may come in handy when classifying the severity of issues, but the date and time values will have to be seperated when we try to decipher seasonal and time of day data.
#
# Changing the date columns from strings to date objects and creating a new column called issue timespan by subtracting published date from status date. There is a breakdown of different time measures for this columns in different columns.

# %%
issue_time = df['status_date'] - df['published_date']
issue_time.abs()
df['issue_timespan'] = issue_time
df.head()
# Out:
#                                                tr_ID  \
# 0  C163BCD1CF90C984E9EDA4DBA311BCA369A7D1A1_15288...
# 1  6B20382196FB454E9FD06A33E60142902A2F0706_15288...
# 2  2A7A84FC69D56A2C379C274D2F0831442D3E7B8E_15871...
# 3  89D3B75BB5932F10D25B5852A9902DA26C3DF11A_15871...
# 4  E7F9EFF0E81057A5C8FE41CABE4D9C6EEA82DAA0_15871...
#
#              published_date  issue_reported   Latitude  Longitude  \
# 0 2018-06-13 06:35:59+00:00   Crash Service  30.283797 -97.741906
# 1 2018-06-13 10:15:36+00:00  Traffic Hazard  30.339593 -97.700963
# 2 2020-04-17 21:25:03+00:00    Crash Urgent  30.329455 -97.638105
# 3 2020-04-17 21:40:52+00:00  Traffic Hazard  30.202806 -97.760701
# 4 2020-04-17 21:00:55+00:00    Crash Urgent  30.184265 -97.687339
#
#                                        Address               status_date  \
# 0                     W 21ST ST & GUADALUPE ST 2018-06-13 09:00:03+00:00
# 1                     400-717 E ANDERSON LN EB 2018-06-13 11:20:03+00:00
# 2  E US 290 HWY SVRD EB & EASTERN HEIGHTS BLVD 2020-04-17 21:55:03+00:00
# 3                          5300-blk S Ih 35 Sb 2020-04-17 21:55:03+00:00
# 4                    4500-4720 S Us 183 Hwy Sb 2020-04-17 23:30:04+00:00
#
#    issue_timespan
# 0 0 days 02:24:04
# 1 0 days 01:04:27
# 2 0 days 00:30:00
# 3 0 days 00:14:11
# 4 0 days 02:29:09

# %%
address_date = df[['Address', 'published_date', 'status_date']]
issue_date.head()
# Out:
#    issue_reported            published_date               status_date
# 0   Crash Service 2018-06-13 06:35:59+00:00 2018-06-13 09:00:03+00:00
# 1  Traffic Hazard 2018-06-13 10:15:36+00:00 2018-06-13 11:20:03+00:00
# 2    Crash Urgent 2020-04-17 21:25:03+00:00 2020-04-17 21:55:03+00:00
# 3  Traffic Hazard 2020-04-17 21:40:52+00:00 2020-04-17 21:55:03+00:00
# 4    Crash Urgent 2020-04-17 21:00:55+00:00 2020-04-17 23:30:04+00:00

# %%
df['issue_reported'].unique()
# Out:
# array(['Crash Service', 'Traffic Hazard', 'Crash Urgent', 'VEHICLE FIRE',
#        'TRFC HAZD/ DEBRIS', 'COLLISION WITH INJURY', 'zSTALLED VEHICLE',
#        'COLLISION', 'COLLISN/ LVNG SCN', 'LOOSE LIVESTOCK',
#        'Stalled Vehicle', 'BLOCKED DRIV/ HWY',
#        'COLLISION/PRIVATE PROPERTY', 'BOAT ACCIDENT', 'FLEET ACC/ INJURY',
#        'Traffic Impediment', 'AUTO/ PED', 'TRAFFIC FATALITY',
#        'OBSTRUCT HWY', 'ICY ROADWAY', 'COLLISN / FTSRA',
#        'N / HZRD TRFC VIOL', 'HIGH WATER', 'FLEET ACC/ FATAL'],
#       dtype=object)

# %%
df['Address'].value_counts()
# Out:
# E Parmer Ln & Dessau Rd                   177
# 9300 S Ih 35 Svrd Sb                      164
# E Riverside Dr & S Pleasant Valley Rd     156
# Fm 969 Rd & N Fm 973 Rd                   154
# Dessau Rd & E Parmer Ln                   150
#                                          ...
# 11100-blk Hialeah Dr                        1
# 2809-2838 E MARTIN LUTHER KING JR BLVD      1
# 6100 S SH 130 NB                            1
# 7300 ED BLUESTEIN BLVD NB                   1
# 17913 Civorno Dr                            1
# Name: Address, Length: 82238, dtype: int64

# %% [markdown]
# Clearly some Adresses are more prone to accidents. These appear to be a series of intersections that can also be
# identified through location data. Example: E Parmer Ln & Dessau Rd (177 issues reported) is location
# 30.387004,-97.648592 (381 issues reported). This suggests that perhaps the location indicator may be more accurate
# even though addresses are easier to communicate.

# %% [markdown]
# #### I wanted to know what day of the week certain issues happened along with the volume of issue per day.
# ##### Hense, these datetime objects are converted into the days of the week
# ##### 0 = Monday, 6 = Sunday and can be found on the published_day/status_day columns

# %%
pub_day = df['published_date'].dt.dayofweek
df['published_day'] = pub_day
pub_day = df['status_date'].dt.dayofweek
df['status_day'] = pub_day

df.head()
# Out:
#                                                tr_ID  \
# 0  C163BCD1CF90C984E9EDA4DBA311BCA369A7D1A1_15288...
# 1  6B20382196FB454E9FD06A33E60142902A2F0706_15288...
# 2  2A7A84FC69D56A2C379C274D2F0831442D3E7B8E_15871...
# 3  89D3B75BB5932F10D25B5852A9902DA26C3DF11A_15871...
# 4  E7F9EFF0E81057A5C8FE41CABE4D9C6EEA82DAA0_15871...
#
#              published_date  issue_reported   Latitude  Longitude  \
# 0 2018-06-13 06:35:59+00:00   Crash Service  30.283797 -97.741906
# 1 2018-06-13 10:15:36+00:00  Traffic Hazard  30.339593 -97.700963
# 2 2020-04-17 21:25:03+00:00    Crash Urgent  30.329455 -97.638105
# 3 2020-04-17 21:40:52+00:00  Traffic Hazard  30.202806 -97.760701
# 4 2020-04-17 21:00:55+00:00    Crash Urgent  30.184265 -97.687339
#
#                                        Address               status_date  \
# 0                     W 21ST ST & GUADALUPE ST 2018-06-13 09:00:03+00:00
# 1                     400-717 E ANDERSON LN EB 2018-06-13 11:20:03+00:00
# 2  E US 290 HWY SVRD EB & EASTERN HEIGHTS BLVD 2020-04-17 21:55:03+00:00
# 3                          5300-blk S Ih 35 Sb 2020-04-17 21:55:03+00:00
# 4                    4500-4720 S Us 183 Hwy Sb 2020-04-17 23:30:04+00:00
#
#    issue_timespan  published_day  status_day
# 0 0 days 02:24:04              2           2
# 1 0 days 01:04:27              2           2
# 2 0 days 00:30:00              4           4
# 3 0 days 00:14:11              4           4
# 4 0 days 02:29:09              4           4

# %% [markdown]
# #### Converting issue_timespan column into seconds

# %% [markdown]
# #### I will also convert the timespan from seconds to minutes and hours.

# %%
df['timespan_sec'] = df.issue_timespan.apply(lambda x: x.total_seconds())
df['timespan_min'] = df['timespan_sec']/60
df['timespan_hrs'] = df['timespan_min']/60
df.head()
# Out:
#                                                tr_ID  \
# 0  C163BCD1CF90C984E9EDA4DBA311BCA369A7D1A1_15288...
# 1  6B20382196FB454E9FD06A33E60142902A2F0706_15288...
# 2  2A7A84FC69D56A2C379C274D2F0831442D3E7B8E_15871...
# 3  89D3B75BB5932F10D25B5852A9902DA26C3DF11A_15871...
# 4  E7F9EFF0E81057A5C8FE41CABE4D9C6EEA82DAA0_15871...
#
#              published_date  issue_reported   Latitude  Longitude  \
# 0 2018-06-13 06:35:59+00:00   Crash Service  30.283797 -97.741906
# 1 2018-06-13 10:15:36+00:00  Traffic Hazard  30.339593 -97.700963
# 2 2020-04-17 21:25:03+00:00    Crash Urgent  30.329455 -97.638105
# 3 2020-04-17 21:40:52+00:00  Traffic Hazard  30.202806 -97.760701
# 4 2020-04-17 21:00:55+00:00    Crash Urgent  30.184265 -97.687339
#
#                                        Address               status_date  \
# 0                     W 21ST ST & GUADALUPE ST 2018-06-13 09:00:03+00:00
# 1                     400-717 E ANDERSON LN EB 2018-06-13 11:20:03+00:00
# 2  E US 290 HWY SVRD EB & EASTERN HEIGHTS BLVD 2020-04-17 21:55:03+00:00
# 3                          5300-blk S Ih 35 Sb 2020-04-17 21:55:03+00:00
# 4                    4500-4720 S Us 183 Hwy Sb 2020-04-17 23:30:04+00:00
#
#    issue_timespan  published_day  status_day  timespan_sec  timespan_min  \
# 0 0 days 02:24:04              2           2        8644.0    144.066667
# 1 0 days 01:04:27              2           2        3867.0     64.450000
# 2 0 days 00:30:00              4           4        1800.0     30.000000
# 3 0 days 00:14:11              4           4         851.0     14.183333
# 4 0 days 02:29:09              4           4        8949.0    149.150000
#
#    timespan_hrs
# 0      2.401111
# 1      1.074167
# 2      0.500000
# 3      0.236389
# 4      2.485833

# %%
df['timespan_min']
# Out:
# 0         144.066667
# 1          64.450000
# 2          30.000000
# 3          14.183333
# 4         149.150000
#              ...
# 249645      5.866667
# 249646      4.833333
# 249647      4.716667
# 249648      5.533333
# 249649      4.083333
# Name: timespan_min, Length: 249061, dtype: float64

# %% [markdown]
# #### THe tr_id is too long and make the head hard to read. I decided to shorten it as well as making it the new index.

# %%
df['short_ID'] = df['tr_ID'].str.slice(0,3)
df = df.drop('tr_ID', 1)
df = df.drop('Status', 1)
df.head()
# Out:
# /var/folders/d2/b8_107b155z0478lwpx5ssrr0000gp/T/ipykernel_20719/2529292978.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df = df.drop('tr_ID', 1)
# /var/folders/d2/b8_107b155z0478lwpx5ssrr0000gp/T/ipykernel_20719/2529292978.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df = df.drop('Status', 1)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/d2/b8_107b155z0478lwpx5ssrr0000gp/T/ipykernel_20719/2529292978.py in <module>
#       1 df['short_ID'] = df['tr_ID'].str.slice(0,3)
#       2 df = df.drop('tr_ID', 1)
# ----> 3 df = df.drop('Status', 1)
#       4 df.head()
#
# ~/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['Status'] not found in axis"

# %%
df.set_index('short_ID', inplace = True)
df.head()

# %% [markdown]
# #### I'm looking to see if there is much difference between plublished_day and status day.
# ##### I was considering dropping some rows if the number was insignificant.

# %%
df.loc[~(df['published_day'] == df['status_day'])]

# %% [markdown]
# #### The number was not insignificant.

# %% [markdown]
# # Exploratory Data Analysis

# %%
#Recheck summary statistics
df.describe()
# Out:
#             Latitude      Longitude              issue_timespan  \
# count  249061.000000  249061.000000                      249061
# mean       30.301823     -97.733356   3 days 04:55:49.009290896
# std         0.093838       0.087198  44 days 19:14:50.566468034
# min        30.003883     -98.816154       -17577 days +05:40:00
# 25%        30.232048     -97.777123             0 days 00:21:00
# 50%        30.294401     -97.734380             0 days 00:42:23
# 75%        30.373815     -97.687431             0 days 01:25:01
# max        31.077333     -97.108986           233 days 08:49:00
#
#        published_day     status_day  timespan_sec  timespan_min   timespan_hrs
# count  249061.000000  249061.000000  2.490610e+05  2.490610e+05  249061.000000
# mean        2.903461       2.940444  2.769490e+05  4.615817e+03      76.930280
# std         1.935689       1.924394  3.870891e+06  6.451484e+04    1075.247380
# min         0.000000       0.000000 -1.518632e+09 -2.531054e+07 -421842.333333
# 25%         1.000000       1.000000  1.260000e+03  2.100000e+01       0.350000
# 50%         3.000000       3.000000  2.543000e+03  4.238333e+01       0.706389
# 75%         5.000000       5.000000  5.101000e+03  8.501667e+01       1.416944
# max         6.000000       6.000000  2.016294e+07  3.360490e+05    5600.816667

# %% [markdown]
# As opposed to the first time we checked our summary statistics when we only had one column, we now have 8 numeric columns to work with. I'm still showing negative values despite my use of the .abs() function. I'll apply it again along with my other measures of timespan.

# %%
df['issue_timespan'] = df['issue_timespan'].abs()
df['timespan_sec'] = df['timespan_sec'].abs()
df['timespan_min'] = df['timespan_min'].abs()
df['timespan_hrs'] = df['timespan_hrs'].abs()
df.describe()
# Out:
#             Latitude      Longitude              issue_timespan  \
# count  249061.000000  249061.000000                      249061
# mean       30.301823     -97.733356   3 days 12:14:03.772806661
# std         0.093838       0.087198  44 days 18:41:59.446604952
# min        30.003883     -98.816154             0 days 00:00:20
# 25%        30.232048     -97.777123             0 days 00:21:00
# 50%        30.294401     -97.734380             0 days 00:42:24
# 75%        30.373815     -97.687431             0 days 01:25:04
# max        31.077333     -97.108986         17576 days 18:20:00
#
#        published_day     status_day  timespan_sec  timespan_min   timespan_hrs
# count  249061.000000  249061.000000  2.490610e+05  2.490610e+05  249061.000000
# mean        2.903461       2.940444  3.032438e+05  5.054063e+03      84.234381
# std         1.935689       1.924394  3.868919e+06  6.448199e+04    1074.699846
# min         0.000000       0.000000  2.000000e+01  3.333333e-01       0.005556
# 25%         1.000000       1.000000  1.260000e+03  2.100000e+01       0.350000
# 50%         3.000000       3.000000  2.544000e+03  4.240000e+01       0.706667
# 75%         5.000000       5.000000  5.104000e+03  8.506667e+01       1.417778
# max         6.000000       6.000000  1.518632e+09  2.531054e+07  421842.333333

# %% [markdown]
# I find the mean of 3.5 days dubious. It is liekely skewed by statistical outliers like the max value we see here of 17,576 days. Since I am looking to produce a realistic time value for how long an incident took to resolve I need to come up with a time limit that makes sense.

# %% [markdown]
# Let's recheck shape.

# %%
df.shape
# Out:
# (249061, 13)

# %%
df.timespan_hrs[df.timespan_hrs < 64].hist(bins=16)
plt.xlabel('Issue Timespan in Hours')
plt.ylabel('Issues')
plt.title('Distribution of Issue Timespan');

# %% [markdown]
# Most of the data points lie within 10 hours, and even that may be too generous based on the graph above.

# %%
#### This is a very high average, something is not right.

# %%
df.timespan_hrs[df.timespan_hrs < 8].hist(bins=16)
plt.xlabel('Issue Timespan in Hours')
plt.ylabel('Issues')
plt.title('Distribution of Issue Timespan');

# %% [markdown]
# The timespan data paints a better picture within an 8 hour timeframe. Hense, I will focus on the first eight hours.

# %%
df[df.timespan_hrs < 8.0].shape
# Out:
# (244201, 13)

# %%
avg_mean = df['issue_timespan'].mean()
print(avg_mean)
avg_mean.total_seconds()
# Out:
# 3 days 12:14:03.772806661
# 303243.772806

# %% [markdown]
# The average issue timespan is a little over 1 hour.

# %%
min_span = df['issue_timespan'].min()
print(min_span)
min_span.total_seconds()
# Out:
# 0 days 00:00:20
# 20.0

# %% [markdown]
# The minimum amount of time to resolve a traffic issue was 20 seconds

# %%
max_span = df['issue_timespan'].max()
print(max_span)
max_span.total_seconds()
# Out:
# 17576 days 18:20:00
# 1518632400.0

# %% [markdown]
# The maximum time spent resolving a traffic issue is 7:59:44

# %%
df.timespan_hrs[df.timespan_hrs < 4].hist(bins=16)
plt.xlabel('Issue Timespan in Hours')
plt.ylabel('Issues')
plt.title('Distribution of Issue Timespan Less Than 4 Hours');

# %%
df.timespan_hrs[df.timespan_hrs < 4].shape
# Out:
# (227900,)

# %% [markdown]
# This plot shows the average timespan of a given issue in hours. As you can see most issues are resolved in less than
# half an hour (0.5 hours). Issues that take over 1 1/2 hours are relatively small in number compared to those that take less than that amount of time.

# %%
df.timespan_min[df.timespan_min < 200].hist(bins=8)
plt.xlabel('Issue Timespan in Minutes')
plt.ylabel('Issues')
plt.title('Distribution of Issue Timespan Less Than 200 minutes');

# %% [markdown]
# I double checked using time in minutes to make sure that the pattern stayed the same, and it did.

# %% [markdown]
# I need to decide what the best cutoff time is and what unit of time makes the most sense. If the average is 01:12:36 then minutes would be the best measure moving forward.

# %% [markdown]
# Perhaps we can see if issues take longer to resolve on weekends then they do on weekdays

# %%
df = df[df.timespan_min <= 200]
print(df.timespan_min.max())
print(df.timespan_min.min())
# Out:
# 200.0
# 0.3333333333333333

# %%
ax = sns.boxplot(x= 'issue_reported', y='timespan_min', data=df)
ax.set_xlabel('Issue Reported', fontsize=5)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
sns.set(rc={'figure.figsize':(26.7,23.27)})

# %%
sns.scatterplot(x='Longitude',y='Latitude', data=df)
# Out:
# <AxesSubplot:xlabel='Longitude', ylabel='Latitude'>

# %% [markdown]
# It looks like are Latitude/Longitude data goes outside the city. Let's zoom in a bit by cutting out some of the smaller instances.

# %%
df_new = df[((df.Latitude >30) & (df.Latitude < 30.8))]
df_new = df_new[((df_new['Longitude'] < -97.25) &(df_new['Longitude'] > -98.25))]

# %%
df_new.describe()
# Out:
#             Latitude      Longitude             issue_timespan  published_day  \
# count  225665.000000  225665.000000                     225665  225665.000000
# mean       30.301493     -97.733247  0 days 00:49:41.113792568       2.906339
# std         0.094106       0.087644  0 days 00:39:41.976219386       1.935231
# min        30.003883     -98.226709            0 days 00:00:20       0.000000
# 25%        30.231747     -97.777323            0 days 00:19:31       1.000000
# 50%        30.293769     -97.734459            0 days 00:37:31       3.000000
# 75%        30.373777     -97.686910            0 days 01:08:34       5.000000
# max        30.798642     -97.293320            0 days 03:20:00       6.000000
#
#           status_day   timespan_sec   timespan_min   timespan_hrs
# count  225665.000000  225665.000000  225665.000000  225665.000000
# mean        2.923054    2981.113793      49.685230       0.828087
# std         1.934905    2381.976219      39.699604       0.661660
# min         0.000000      20.000000       0.333333       0.005556
# 25%         1.000000    1171.000000      19.516667       0.325278
# 50%         3.000000    2251.000000      37.516667       0.625278
# 75%         5.000000    4114.000000      68.566667       1.142778
# max         6.000000   12000.000000     200.000000       3.333333

# %%
sns.scatterplot(x='Longitude',y='Latitude', data=df_new)
# Out:
# <AxesSubplot:xlabel='Longitude', ylabel='Latitude'>

# %%
#spots = pd.DataFrame(df['Latitude','Longitude'])
gdf = gpd.GeoDataFrame(df, geometry=gpd.df_from_xy(df.Latitude, df.Longitude))
gdf
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/d2/b8_107b155z0478lwpx5ssrr0000gp/T/ipykernel_20719/2463923965.py in <module>
#       1 #spots = pd.DataFrame(df['Latitude','Longitude'])
# ----> 2 gdf = gpd.GeoDataFrame(df, geometry=gpd.df_from_xy(df.Latitude, df.Longitude))
#       3 gdf
#
# AttributeError: module 'geopandas' has no attribute 'df_from_xy'

# %%
ax = sns.relplot(x= 'issue_reported', y='timespan_min', data=df, kind='scatter', col='published_day')
plt.show()

# %%
df.published_day.hist(bins=20)
plt.xlabel('Day of Week')
plt.ylabel('Proportions')
plt.title('Distribution of Reported Issue Day of Week');

# %% [markdown]
# ##Plot Key
# - 0 = Monday
# - 1 = Tuesday
# - 2 = Wednesday
# - 3 = Thursday
# - 4 = Friday
# - 5 = Saturday
# - 6 = Sunday
#
#
# We can see that the highest instances of traffic incidents happen of Friday, which is to be expected due to a lively nightlife. Conversely, Sunday has the least amount of incidents as most people are resting and preparing for the work week.
#
# Monday and Tuesday hold steady at around 35,0000
# Wednesday and Thursday there is a slight increase to around 37,000
# Saturday has less instances than weekdays at about 33,000

# %% [markdown]
# # Volume of Unique Issues Reported Over 100

# %%
df = df.groupby('issue_reported').filter(lambda x : len(x)>100)
df.shape
# Out:
# (225457, 13)

# %%
df['issue_reported'].value_counts()
# Out:
# Traffic Hazard                70993
# Crash Urgent                  52543
# Crash Service                 32483
# COLLISION                     20576
# TRFC HAZD/ DEBRIS             16339
# zSTALLED VEHICLE               8027
# LOOSE LIVESTOCK                5567
# COLLISION WITH INJURY          5286
# Traffic Impediment             4713
# COLLISN/ LVNG SCN              3976
# Stalled Vehicle                2795
# COLLISION/PRIVATE PROPERTY      917
# VEHICLE FIRE                    753
# BLOCKED DRIV/ HWY               489
# Name: issue_reported, dtype: int64

# %% [markdown]
# Unsure about the meaning of some of these headings mean but it may be worth looking at the average timespan of each unique issue. This list shows issues that ocurred at least 500 times.

# %% [markdown]
# ## Visualizing the Volume of Issues Reported

# %%
issue_counts = df['issue_reported'].value_counts()
issue_counts.plot( rot=90)
plt.xlabel("Report Issues by Group")
plt.ylabel("Proportions")
plt.title('Volume of Issues Reported')
plt.show()

# %% [markdown]
# This is a visual representation of incident volume. Traffic Hazard happen by far the most, while highway obstruction ocurrs the least.

# %%
df.issue_reported.hist(figsize=(35,20))
plt.xticks(fontsize = 20, rotation=45)
plt.yticks(fontsize = 20)
plt.show()

# %% [markdown]
# #The histograph above includes issues that we too sparse to be part of the initial line plot. As one can see, traffic #impediment barely happens and we know

# %%
#df.plot.line(x='timespan_min', y='issue_reported')
#Why doesn't this work?

# %% [markdown]
# I wanted to see how many rows had different published/status days. I was considering dropping the rows if the
# instances were low. They were not. I will essentially just be using the published day for most of the anaysis.

# %% [markdown]
# The next thing I need to do is take latitude and logitude and put them in a scatter plot over a map.

# %%
crs = {'init': 'epsg:4326'}

# %%
geometry = [Point(xy) for xy in zip(df['Longitude'], df['Latitude'])]
geometry[:3]
# Out:
# [<shapely.geometry.point.Point at 0x7fae03ea8640>,
#  <shapely.geometry.point.Point at 0x7fae056a4610>,
#  <shapely.geometry.point.Point at 0x7fae05688550>]

# %%
geo_df = gpd.GeoDataFrame(df,
                         crs = crs,
                         geometry = geometry)
geo_df.head()
# Out:
# /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages/pyproj/crs/crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/d2/b8_107b155z0478lwpx5ssrr0000gp/T/ipykernel_20719/339075898.py in <module>
# ----> 1 geo_df = gpd.GeoDataFrame(df,
#       2                          crs = crs,
#       3                          geometry = geometry)
#       4 geo_df.head()
#
# ~/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages/geopandas/geodataframe.py in __init__(self, data, geometry, crs, *args, **kwargs)
#     182                 _crs_mismatch_warning()
#     183                 # TODO: raise error in 0.9 or 0.10.
# --> 184             self.set_geometry(geometry, inplace=True)
#     185
#     186         if geometry is None and crs:
#
# ~/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages/geopandas/geodataframe.py in set_geometry(self, col, drop, inplace, crs)
#     318         level = _ensure_geometry(level, crs=crs)
#     319         index = frame.index
# --> 320         frame[geo_column_name] = level
#     321         if frame.index is not index and len(frame.index) == len(index):
#     322             # With pandas < 1.0 and an empty frame (no rows), the index gets reset
#
# ~/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages/geopandas/geodataframe.py in __setitem__(self, key, value)
#    1349             except TypeError:
#    1350                 warnings.warn("Geometry column does not contain geometry.")
# -> 1351         super().__setitem__(key, value)
#    1352
#    1353     #
#
# ~/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3610         else:
#    3611             # set column
# -> 3612             self._set_item(key, value)
#    3613
#    3614     def _setitem_slice(self, key: slice, value):
#
# ~/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3782         ensure homogeneity.
#    3783         """
# -> 3784         value = self._sanitize_column(value)
#    3785
#    3786         if (
#
# ~/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4507
#    4508         if is_list_like(value):
# -> 4509             com.require_length_match(value, self.index)
#    4510         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4511
#
# ~/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages/pandas/core/common.py in require_length_match(data, index)
#     529     """
#     530     if len(data) != len(index):
# --> 531         raise ValueError(
#     532             "Length of values "
#     533             f"({len(data)}) "
#
# ValueError: Length of values (225457) does not match length of index (249061)

# %%
fig,ax =plt.subplots(figsize=(15,15))
street_map.plot(ax = ax, alpha = 0.4, color='grey')
geo_df[geo_df['WnvPresent'] ==0].plot(ax = ax, markersize = 20, color = 'blue',marker = '=o', label = 'Neg')
geo_df[geo_df['WnvPresent'] ==1].plot(ax = ax, markersize = 20, color = 'red',marker = '^', label = 'Pos')
plt.legend(prop={'size': 15})

# %% [markdown]
# There are many 'Latitude' and some 'Logitude' null values so I tried splitting the 'Location' column into two different strings and converting them to numbers. This resulted in even more null values so I scrapped the idea.
