# %% [markdown]
# pip install geopandas

# %%
pip install geopandas
# Out:
# Requirement already satisfied: geopandas in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (0.10.2)
# Requirement already satisfied: fiona>=1.8 in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (from geopandas) (1.8.20)
# Requirement already satisfied: shapely>=1.6 in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (from geopandas) (1.8.0)
# Requirement already satisfied: pandas>=0.25.0 in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (from geopandas) (1.3.5)
# Requirement already satisfied: pyproj>=2.2.0 in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (from geopandas) (3.3.0)
# Requirement already satisfied: attrs>=17 in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (21.2.0)
# Requirement already satisfied: click-plugins>=1.0 in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: setuptools in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (58.0.4)
# Requirement already satisfied: munch in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: click>=4.0 in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (8.0.3)
# Requirement already satisfied: six>=1.7 in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (1.16.0)
# Requirement already satisfied: cligj>=0.5 in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: certifi in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (2021.10.8)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (from pandas>=0.25.0->geopandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (from pandas>=0.25.0->geopandas) (1.22.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (from pandas>=0.25.0->geopandas) (2021.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-5.5.0-py2.py3-none-any.whl (26.5 MB)
#      |████████████████████████████████| 26.5 MB 4.1 MB/s eta 0:00:01
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: six in /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages (from plotly) (1.16.0)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.5.0 tenacity-8.0.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# This time series analysis hopes to find a coorelation between accident location, type of issue, time taken to resolve issue, time of day, day of week, and month of year. This will help predict when and where an accident is likely to happen.

# %% [markdown]
# # Import necessary libraries

# %%
import pandas as pd
import numpy as np
import datetime
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import t
import scipy.stats as ss
from numpy.random import seed

import descartes
import geopandas as gpd
from shapely.geometry import Point, Polygon

# %matplotlib inline

# %% [markdown]
# # Data Collection/Organization

# %%
file = 'Data/traffic_data_cleaned.csv'

# %%
df = pd.read_csv(file)
df.head()
# Out:
#   short_ID             published_date  issue_reported   Latitude  Longitude  \
# 0      C16  2018-06-13 06:35:59+00:00   Crash Service  30.283797 -97.741906
# 1      6B2  2018-06-13 10:15:36+00:00  Traffic Hazard  30.339593 -97.700963
# 2      2A7  2020-04-17 21:25:03+00:00    Crash Urgent  30.329455 -97.638105
# 3      89D  2020-04-17 21:40:52+00:00  Traffic Hazard  30.202806 -97.760701
# 4      E7F  2020-04-17 21:00:55+00:00    Crash Urgent  30.184265 -97.687339
#
#                                        Address                status_date  \
# 0                     W 21ST ST & GUADALUPE ST  2018-06-13 09:00:03+00:00
# 1                     400-717 E ANDERSON LN EB  2018-06-13 11:20:03+00:00
# 2  E US 290 HWY SVRD EB & EASTERN HEIGHTS BLVD  2020-04-17 21:55:03+00:00
# 3                          5300-blk S Ih 35 Sb  2020-04-17 21:55:03+00:00
# 4                    4500-4720 S Us 183 Hwy Sb  2020-04-17 23:30:04+00:00
#
#     issue_timespan  published_day  timespan_sec  timespan_min
# 0  0 days 02:24:04              2        8644.0    144.066667
# 1  0 days 01:04:27              2        3867.0     64.450000
# 2  0 days 00:30:00              4        1800.0     30.000000
# 3  0 days 00:14:11              4         851.0     14.183333
# 4  0 days 02:29:09              4        8949.0    149.150000

# %%
df.shape
# Out:
# (225445, 11)

# %% [markdown]
# There are 249,650 rows and 9 columns

# %%
df.describe()
# Out:
#             Latitude      Longitude  published_day   timespan_sec  \
# count  225445.000000  225445.000000  225445.000000  225445.000000
# mean       30.301440     -97.733156       2.906261    2979.937018
# std         0.094080       0.087511       1.935056    2381.053573
# min        30.003883     -98.226709       0.000000      20.000000
# 25%        30.231715     -97.777183       1.000000    1170.000000
# 50%        30.293602     -97.734450       3.000000    2250.000000
# 75%        30.373691     -97.686922       5.000000    4111.000000
# max        30.798642     -97.293320       6.000000   12000.000000
#
#         timespan_min
# count  225445.000000
# mean       49.665617
# std        39.684226
# min         0.333333
# 25%        19.500000
# 50%        37.500000
# 75%        68.516667
# max       200.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225445 entries, 0 to 225444
# Data columns (total 11 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   short_ID        225445 non-null  object
#  1   published_date  225445 non-null  object
#  2   issue_reported  225445 non-null  object
#  3   Latitude        225445 non-null  float64
#  4   Longitude       225445 non-null  float64
#  5   Address         225445 non-null  object
#  6   status_date     225445 non-null  object
#  7   issue_timespan  225445 non-null  object
#  8   published_day   225445 non-null  int64
#  9   timespan_sec    225445 non-null  float64
#  10  timespan_min    225445 non-null  float64
# dtypes: float64(4), int64(1), object(6)
# memory usage: 18.9+ MB

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.issue_reported.unique()
# Out:
# array(['Crash Service', 'Traffic Hazard', 'Crash Urgent',
#        'TRFC HAZD/ DEBRIS', 'COLLISION WITH INJURY', 'zSTALLED VEHICLE',
#        'COLLISION', 'COLLISN/ LVNG SCN', 'LOOSE LIVESTOCK',
#        'Stalled Vehicle', 'BLOCKED DRIV/ HWY',
#        'COLLISION/PRIVATE PROPERTY', 'VEHICLE FIRE', 'Traffic Impediment'],
#       dtype=object)

# %%
sns.scatterplot(x='Longitude',y='Latitude', data= df[df.issue_reported == 'Crash Service'])
# Out:
# <AxesSubplot:xlabel='Longitude', ylabel='Latitude'>

# %%
ax = sns.relplot(x='Longitude',y='Latitude', data=df, kind='scatter', col='issue_reported')

# %%
ax = sns.relplot(x='Longitude',y='Latitude', data=df, kind='scatter', col='published_day')

# %% [markdown]
# Breaking down published date into time blocks. I need to slice and isolate the times of day from the datetime object.

# %%
datetime_obj = datetime.strptime(df.published_date, "%d%b%Y%H%M%S")
print("date time : {}".format(datetime_obj))
time = datetime_obj.time()
print("Time : {}".format(time))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/d2/b8_107b155z0478lwpx5ssrr0000gp/T/ipykernel_20719/1864913043.py in <module>
# ----> 1 datetime_obj = datetime.strptime(df.published_date, "%d%b%Y%H%M%S")
#       2 print("date time : {}".format(datetime_obj))
#       3 time = datetime_obj.time()
#       4 print("Time : {}".format(time))
#
# TypeError: strptime() argument 1 must be str, not Series

# %%
ax = sns.boxplot(x= 'issue_reported', y='timespan_min', data=df)
ax.set_xlabel('Issue Reported', fontsize=5)
ax.set_xticklabels(ax.get_xticklabels(),rotation=45)
sns.set(rc={'figure.figsize':(30.7,27.27)})

# %%
ax = sns.relplot(x= 'issue_reported', y='timespan_min', data=df, kind='scatter', col='published_day')
ax.set_xticklabels(rotation=30)

plt.show()

# %%
df.published_day.hist(bins=20)
plt.xlabel('Day of Week')
plt.ylabel('Proportions')
plt.title('Distribution of Reported Issue Day of Week');

# %% [markdown]
# ##Plot Key
# - 0 = Monday
# - 1 = Tuesday
# - 2 = Wednesday
# - 3 = Thursday
# - 4 = Friday
# - 5 = Saturday
# - 6 = Sunday
#
#
# We can see that the highest instances of traffic incidents happen of Friday, which is to be expected due to a lively nightlife. Conversely, Sunday has the least amount of incidents as most people are resting and preparing for the work week.
#
# Monday and Tuesday hold steady at around 35,0000
# Wednesday and Thursday there is a slight increase to around 37,000
# Saturday has less instances than weekdays at about 33,000

# %% [markdown]
# The next thing I need to do is take latitude and logitude and put them in a scatter plot over a map.

# %%
crs = {'init': 'epsg:4326'}

# %%
geometry = [Point(xy) for xy in zip(df['Longitude'], df['Latitude'])]
geometry[:3]
# Out:
# [<shapely.geometry.point.Point at 0x7fae05e71fd0>,
#  <shapely.geometry.point.Point at 0x7fae00f70f70>,
#  <shapely.geometry.point.Point at 0x7fae00f70d90>]

# %%
geo_df = gpd.GeoDataFrame(df,
                         crs = crs,
                         geometry = geometry)
geo_df.head()
# Out:
# /Users/tshields/opt/anaconda3/envs/Springboard/lib/python3.8/site-packages/pyproj/crs/crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
#   short_ID             published_date  issue_reported   Latitude  Longitude  \
# 0      C16  2018-06-13 06:35:59+00:00   Crash Service  30.283797 -97.741906
# 1      6B2  2018-06-13 10:15:36+00:00  Traffic Hazard  30.339593 -97.700963
# 2      2A7  2020-04-17 21:25:03+00:00    Crash Urgent  30.329455 -97.638105
# 3      89D  2020-04-17 21:40:52+00:00  Traffic Hazard  30.202806 -97.760701
# 4      E7F  2020-04-17 21:00:55+00:00    Crash Urgent  30.184265 -97.687339
#
#                                        Address                status_date  \
# 0                     W 21ST ST & GUADALUPE ST  2018-06-13 09:00:03+00:00
# 1                     400-717 E ANDERSON LN EB  2018-06-13 11:20:03+00:00
# 2  E US 290 HWY SVRD EB & EASTERN HEIGHTS BLVD  2020-04-17 21:55:03+00:00
# 3                          5300-blk S Ih 35 Sb  2020-04-17 21:55:03+00:00
# 4                    4500-4720 S Us 183 Hwy Sb  2020-04-17 23:30:04+00:00
#
#     issue_timespan  published_day  timespan_sec  timespan_min  \
# 0  0 days 02:24:04              2        8644.0    144.066667
# 1  0 days 01:04:27              2        3867.0     64.450000
# 2  0 days 00:30:00              4        1800.0     30.000000
# 3  0 days 00:14:11              4         851.0     14.183333
# 4  0 days 02:29:09              4        8949.0    149.150000
#
#                      geometry
# 0  POINT (-97.74191 30.28380)
# 1  POINT (-97.70096 30.33959)
# 2  POINT (-97.63810 30.32945)
# 3  POINT (-97.76070 30.20281)
# 4  POINT (-97.68734 30.18426)

# %% [markdown]
# import plotly.express as px
# px.set_mapbox_access_token('pk.eyJ1IjoidG9tc2hpZWxkczcxIiwiYSI6ImNreXl0anNxajBjaXQybnJtdW5zeXdqb3UifQ.6vXBOrDTeliFVziQaB6ecg')
# gpd['size']=65
# #mapbox tokens found here https://account.mapbox.com/access-tokens
# fig = px,scatter_mapbox(gdf, lat = gpd.geometry.y, lon=gpd.geometry.x, cmapbox_style='outdoors', size='size', zoom=10)
# fig.show()

# %% [markdown]
# fig,ax =plt.subplots(figsize=(15,15))
# street_map.plot(ax = ax, alpha = 0.4, color='grey')
# geo_df[geo_df['WnvPresent'] ==0].plot(ax = ax, markersize = 20, color = 'blue',marker = '=o', label = 'Neg')
# geo_df[geo_df['WnvPresent'] ==1].plot(ax = ax, markersize = 20, color = 'red',marker = '^', label = 'Pos')
# plt.legend(prop={'size': 15})

# %%
#spots = pd.DataFrame(df['Latitude','Longitude'])
#gdf = gpd.GeoDataFrame(df, geometry=gpd.df_from_xy(df.Latitude, df.Longitude))
#gdf
